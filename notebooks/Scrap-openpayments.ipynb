# %%
#  The General Payment Data – Detailed Dataset 2020 Reporting Year 
# dataset, from CMS Open Payments portal, is available for downlaod here:
# https://openpaymentsdata.cms.gov/dataset/txng-a8vj

# it is a 3.1 Gb download

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#OPD = pd.read_csv("OP_DTL_GNRL_PGYR2020_P06302021.csv")
OPD = pd.read_csv("sample.csv")
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
OPD
# Out:
#      Change_Type               Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0            NEW  Covered Recipient Teaching Hospital               160045.0
# 1            NEW          Covered Recipient Physician                    NaN
# 2            NEW          Covered Recipient Physician                    NaN
# 3            NEW          Covered Recipient Physician                    NaN
# 4            NEW          Covered Recipient Physician                    NaN
# ...          ...                                  ...                    ...
# 9994         NEW          Covered Recipient Physician                    NaN
# 9995         NEW          Covered Recipient Physician                    NaN
# 9996         NEW          Covered Recipient Physician                    NaN
# 9997         NEW          Covered Recipient Physician                    NaN
# 9998         NEW          Covered Recipient Physician                    NaN
#
# ...

# %%
OPD.columns
# Out:
# Index(['Change_Type', 'Covered_Recipient_Type', 'Teaching_Hospital_CCN',
#        'Teaching_Hospital_ID', 'Teaching_Hospital_Name',
#        'Physician_Profile_ID', 'Physician_First_Name', 'Physician_Middle_Name',
#        'Physician_Last_Name', 'Physician_Name_Suffix',
#        'Recipient_Primary_Business_Street_Address_Line1',
#        'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
#        'Recipient_Province', 'Recipient_Postal_Code', 'Physician_Primary_Type',
#        'Physician_Specialty', 'Physician_License_State_code1',
#        'Physician_License_State_code2', 'Physician_License_State_code3',
#        'Physician_License_State_code4', 'Physician_License_State_code5',
#        'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
# ...

# %%
OPD.Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1.value_counts()
# Out:
# Device            6204
# Drug              2683
# Medical Supply     125
# Biological          21
# Name: Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1, dtype: int64

# %%
OPD.Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1.value_counts()
# Out:
# VNS Therapy                                   2874
# Natesto                                        580
# CitraNatal                                     460
# InPen                                          460
# Reblozyl                                       457
#                                               ...
# HICON                                            1
# NextSeq 550Dx Instrument 15073937 assembly       1
# Ceracell Ortho Foam                              1
# DRAXIMAGE MAA                                    1
# Medyssey Artemis screw system                    1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1, Length: 109, dtype: int64

# %%
OPD.Recipient_Zip_Code.value_counts()
# Out:
# 90241-4982    72
# 64108-4619    52
# 77030         47
# 90048         40
# 23235         37
#               ..
# 91320          1
# 47403-2317     1
# 48162-4222     1
# 75115-2019     1
# 35802          1
# Name: Recipient_Zip_Code, Length: 3899, dtype: int64

# %%
OPD.ZIP = OPD.Recipient_Zip_Code[0:6]

# %%
OPD.ZIP.value_counts()
# Out:
# 94010    4
# 52406    1
# 28211    1
# Name: Recipient_Zip_Code, dtype: int64

# %%
# I want to make sure this is digestible before I fill my memory with it..
OPD.dtypes
# Out:
# Change_Type                                                  object
# Covered_Recipient_Type                                       object
# Teaching_Hospital_CCN                                       float64
# Teaching_Hospital_ID                                        float64
# Teaching_Hospital_Name                                       object
#                                                              ...
# Product_Category_or_Therapeutic_Area_5                       object
# Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5     object
# Associated_Drug_or_Biological_NDC_5                         float64
# Program_Year                                                  int64
# Payment_Publication_Date                                     object
# Length: 75, dtype: object

# %%
# Most of these seem to be strings encoded as pandas "objects"... 
# Let us look at some one-dimensional value_counts..

# %%
OPD.Teaching_Hospital_Name.value_counts()
# Out:
# Univ Of Mi Hospitals & Hlth Ctrs        4
# Northwestern Memorial Hospital          4
# The Nebraska Medical Center             2
# Bryan Medical Center                    1
# Ucsd Medical Center                     1
# MEMORIAL HEALTH UNIV MED CENTER         1
# Hospital Of The Univ Of Penna           1
# Memorial Hermann Hospital Sys           1
# GRADY MEMORIAL HOSPITAL                 1
# AKRON GENERAL MEDICAL CENTER            1
# Saint Joseph Hospital                   1
# COLISEUM MEDICAL CENTERS                1
# City Of Hope National Medical Ctr       1
# Stanford Health Care                    1
# EMORY UNIVERSITY HOSPITAL               1
# Childrens Hospital of the Kings Da      1
# Childrens Mercy Hospital                1
# Massachusetts General Hospital          1
# ST MARYS HEALTH CARE SYSTEM INC         1
# The Christ Hospital                     1
# St. Lukes Methodist Hospital            1
# ST. JOSEPHS OF ATLANTA                  1
# ...

# %%
OPD.Physician_Profile_ID.value_counts()
# Out:
# 271378.0    45
# 314793.0    40
# 354186.0    36
# 100859.0    31
# 333693.0    30
#             ..
# 149809.0     1
# 349119.0     1
# 6223.0       1
# 504770.0     1
# 192.0        1
# Name: Physician_Profile_ID, Length: 6327, dtype: int64

# %%
len(OPD)
# Out:
# 9999

# %%
# 6300 distinct physician_ids in 10,000 records...
